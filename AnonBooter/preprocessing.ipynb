# %%
import pandas as pd

# %%
df = pd.read_csv('AnonBooterWithBenignCombined.csv')

# %%
df.duplicated().sum()
# Out:
# np.int64(202)

# %%
global_dups = df.duplicated().sum()

label_dups = df.groupby("Label").apply(
    lambda x: x.duplicated().sum()
).sum()

print(global_dups, label_dups)
# Out:
# 202 202
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11488\3639644098.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   label_dups = df.groupby("Label").apply(

# %%
print(df["Label"].isna().sum())
# Out:
# 0

# %%
# Use dropna=False to include the rows with missing labels
df.groupby("Label", dropna=False).apply(lambda x: x.duplicated().sum())
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11488\2161749747.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("Label", dropna=False).apply(lambda x: x.duplicated().sum())
# Label
# 0    202
# 1      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(202)

# %%
df.shape
# Out:
# (4044152, 84)

# %%
rows_with_nan = df.isna().any(axis=1).sum()

print(f"Total rows with at least one NaN: {rows_with_nan}")
# Out:
# Total rows with at least one NaN: 1079

# %%
total_nans = df.isna().sum().sum()
print(f"Total missing values in DF: {total_nans}")
# Out:
# Total missing values in DF: 1749

# %%
# This will show only the columns that have at least one NaN
print(df.columns[df.isna().any()].tolist())
# Out:
# ['Flow Byts/s', 'Flow Pkts/s']

# %%
df['Flow Byts/s'].isna().sum()
# Out:
# np.int64(1079)

# %%
# 1. Filter the dataframe for only rows where Flow Bytes/s is NaN
nan_data = df[df['Flow Byts/s'].isna()]

# 2. Count the labels within that subset
distribution = nan_data['Label'].value_counts()

print("Distribution of NaNs per Label:")
print(distribution)

# 3. Optional: See the percentage of each label that is "broken"
total_per_label = df['Label'].value_counts()
nan_percentage = (distribution / total_per_label) * 100
print("\nPercentage of each Label that has NaNs:")
print(nan_percentage.dropna())
# Out:
# Distribution of NaNs per Label:
# Label
# 1    670
# 0    409
# Name: count, dtype: int64
#
# Percentage of each Label that has NaNs:
# Label
# 0    0.017993
# 1    0.037831
# Name: count, dtype: float64

# %%
df['Label'].value_counts()
# Out:
# Label
# 0    2273097
# 1    1771055
# Name: count, dtype: int64

# %%
# 1. Select only the columns that contain text/objects
string_columns = df.select_dtypes(include=['object']).columns

# 2. Check if the stripped string is empty
# .str.strip() removes spaces; .eq('') checks if it is then empty
blanks_mask = df[string_columns].apply(lambda x: x.str.strip().eq('')).any(axis=1)

total_blank_rows = blanks_mask.sum()
print(f"Total rows with at least one blank entry: {total_blank_rows}")
# Out:
# Total rows with at least one blank entry: 0

# %%
import numpy as np

# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Total number of infinite values
total_inf = np.isinf(numeric_df).values.sum()

print(f"Total infinite entries: {total_inf}")
# Out:
# Total infinite entries: 3145

# %%
# Check if any value in a row is infinite
inf_rows = np.isinf(numeric_df).any(axis=1).sum()

print(f"Total rows with at least one infinite value: {inf_rows}")
# Out:
# Total rows with at least one infinite value: 1777

# %%
import numpy as np

# Select only numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns

# Count infinite values (positive and negative) per column
inf_counts = np.isinf(df[numeric_cols]).sum()

# Display only columns that have at least one infinite value
print("Infinite values per column:")
print(inf_counts[inf_counts > 0])
# Out:
# Infinite values per column:
# Flow Byts/s    1368
# Flow Pkts/s    1777
# dtype: int64

# %%
# 1. Create a boolean mask for any row that has at least one infinite value
inf_rows_mask = np.isinf(df[numeric_cols]).any(axis=1)

# 2. Filter the dataframe using that mask and count the Labels
inf_label_dist = df[inf_rows_mask]['Label'].value_counts()

print("\nDistribution of Infinite entries per Label:")
print(inf_label_dist)
# Out:
# Distribution of Infinite entries per Label:
# Label
# 0    1777
# Name: count, dtype: int64

# %%
total_inf_cells = np.isinf(df[numeric_cols]).values.sum()
total_rows_with_inf = inf_rows_mask.sum()

print(f"\nTotal infinite cells in dataset: {total_inf_cells}")
print(f"Total rows affected by infinity: {total_rows_with_inf}")
# Out:
# Total infinite cells in dataset: 3145
# Total rows affected by infinity: 1777

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
rows_with_nan = df.isna().any(axis=1).sum()

print(f"Total rows with at least one NaN: {rows_with_nan}")
# Out:
# Total rows with at least one NaN: 2447

# %%
total_nans = df.isna().sum().sum()
print(f"Total missing values in DF: {total_nans}")
# Out:
# Total missing values in DF: 4894

# %%
# This will show only the columns that have at least one NaN
print(df.columns[df.isna().any()].tolist())
# Out:
# ['Flow Byts/s', 'Flow Pkts/s']

# %%
# 1. Filter the dataframe for only rows where Flow Bytes/s is NaN
nan_data = df[df['Flow Byts/s'].isna()]

# 2. Count the labels within that subset
distribution = nan_data['Label'].value_counts()

print("Distribution of NaNs per Label:")
print(distribution)

# 3. Optional: See the percentage of each label that is "broken"
total_per_label = df['Label'].value_counts()
nan_percentage = (distribution / total_per_label) * 100
print("\nPercentage of each Label that has NaNs:")
print(nan_percentage.dropna())
# Out:
# Distribution of NaNs per Label:
# Label
# 0    1777
# 1     670
# Name: count, dtype: int64
#
# Percentage of each Label that has NaNs:
# Label
# 0    0.078175
# 1    0.037831
# Name: count, dtype: float64

# %%
total_nans = df.isna().sum().sum()
print(f"Total missing values in DF: {total_nans}")
# Out:
# Total missing values in DF: 4894

# %%
df.duplicated().sum()
# Out:
# np.int64(202)

# %%
df.describe()
# Out:
#            Src Port      Dst Port      Protocol  Flow Duration  Tot Fwd Pkts  \
# count  4.044152e+06  4.044152e+06  4.044152e+06   4.044152e+06  4.044152e+06
# mean   2.247836e+04  1.949511e+04  1.352314e+01   7.895902e+06  1.566706e+01
# std    2.671553e+04  2.256984e+04  5.124492e+00   2.529228e+07  7.290489e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  -1.300000e+01  1.000000e+00
# 25%    5.300000e+01  8.000000e+01  6.000000e+00   5.680000e+02  2.000000e+00
# 50%    4.430000e+02  6.264000e+03  1.700000e+01   5.406000e+03  5.000000e+00
# 75%    5.307100e+04  4.063900e+04  1.700000e+01   6.798125e+04  1.400000e+01
# max    6.553500e+04  6.553500e+04  1.700000e+01   1.200000e+08  2.197590e+05
#
#        Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# count  4.044152e+06     4.044152e+06     4.044152e+06     4.044152e+06
# mean   7.260695e+00     7.137243e+03     1.103349e+04     5.688187e+02
# std    8.344411e+02     8.921622e+04     1.893354e+06     7.665196e+02
# min    0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%    1.000000e+00     6.000000e+01     9.200000e+01     3.500000e+01
# 50%    1.000000e+00     6.720000e+02     3.680000e+02     1.990000e+02
# 75%    2.000000e+00     1.215200e+04     1.274000e+03     1.026000e+03
# max    2.919220e+05     2.940656e+07     6.554530e+08     2.482000e+04
#
#        Fwd Pkt Len Min  ...  Fwd Seg Size Min   Active Mean    Active Std  \
# count     4.044152e+06  ...      4.044152e+06  4.044152e+06  4.044152e+06
# mean      4.517978e+02  ...     -1.922852e+03  4.558372e+04  2.759848e+04
# std       5.720664e+02  ...      9.077419e+05  5.171916e+05  3.419435e+05
# min       0.000000e+00  ...     -5.368707e+08  0.000000e+00  0.000000e+00
# 25%       6.000000e+00  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 50%       4.500000e+01  ...      2.000000e+01  0.000000e+00  0.000000e+00
# 75%       1.026000e+03  ...      3.200000e+01  0.000000e+00  0.000000e+00
# max       2.325000e+03  ...      1.380000e+02  1.100000e+08  7.420000e+07
#
#          Active Max    Active Min     Idle Mean      Idle Std      Idle Max  \
# count  4.044152e+06  4.044152e+06  4.044152e+06  4.044152e+06  4.044152e+06
# mean   9.583022e+04  3.002930e+04  3.561164e+06  1.873261e+05  3.699436e+06
# std    8.627324e+05  4.437989e+05  1.426758e+07  2.538583e+06  1.470817e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.100000e+08  1.100000e+08  1.200000e+08  7.694955e+07  1.200000e+08
#
#            Idle Min         Label
# count  4.044152e+06  4.044152e+06
# mean   3.401993e+06  4.379299e-01
# std    1.405625e+07  4.961324e-01
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  1.000000e+00
# max    1.200000e+08  1.000000e+00
#
# [8 rows x 80 columns]

# %%
df.shape
# Out:
# (4044152, 84)

# %%
# Save the cleaned DataFrame back to your file
df.to_csv('AnonBooterWithBenignCombined.csv', index=False)

# %%
pd.set_option('display.max_rows', None)

# 2. Run your zero-count check again
# Replace 'df' with the name of your dataframe (e.g., X_normalized or data)
zero_counts = (df == 0).sum()

# 3. Print the result
print(zero_counts)
# Out:
# Flow ID                    0
# Src IP                     0
# Src Port                4104
# Dst IP                     0
# Dst Port                4104
# Protocol                4104
# Timestamp                  0
# Flow Duration           2447
# Tot Fwd Pkts               0
# Tot Bwd Pkts          330952
# TotLen Fwd Pkts       298303
# TotLen Bwd Pkts       573652
# Fwd Pkt Len Max       298303
# Fwd Pkt Len Min       904141
# Fwd Pkt Len Mean      298303
# Fwd Pkt Len Std      3325758
# Bwd Pkt Len Max       573652
# Bwd Pkt Len Min      1048600
# Bwd Pkt Len Mean      573652
# Bwd Pkt Len Std      3495262
# Flow Byts/s           286428
# Flow Pkts/s                0
# Flow IAT Mean           2447
# Flow IAT Std          840597
# Flow IAT Max            2446
# Flow IAT Min          175249
# Fwd IAT Tot           614374
# Fwd IAT Mean          614374
# Fwd IAT Std          1659520
# Fwd IAT Max           614374
# Fwd IAT Min           743076
# Bwd IAT Total        2724650
# Bwd IAT Mean         2724650
# Bwd IAT Std          3488001
# Bwd IAT Max          2724650
# Bwd IAT Min          2734885
# Fwd PSH Flags        3919390
# Bwd PSH Flags        4044152
# Fwd URG Flags        4043837
# Bwd URG Flags        4044152
# Fwd Header Len          4166
# Bwd Header Len        333495
# Fwd Packets/s           2562
# Bwd Packets/s         332585
# Pkt Len Min           921203
# Pkt Len Max           286862
# Pkt Len Mean          286862
# Pkt Len Std          2356286
# Pkt Len Var          2356286
# FIN Flag Cnt         4002964
# SYN Flag Cnt         3919380
# RST Flag Cnt         4043466
# PSH Flag Cnt         3457674
# ACK Flag Cnt         3391904
# URG Flag Cnt         3780560
# CWE Flag Count       4043837
# ECE Flag Cnt         4043463
# Down/Up Ratio        2506602
# Pkt Size Avg          286862
# Fwd Seg Size Avg      298303
# Bwd Seg Size Avg      573652
# Fwd Byts/b Avg       4044152
# Fwd Pkts/b Avg       4044152
# Fwd Blk Rate Avg     4044152
# Bwd Byts/b Avg       4044152
# Bwd Pkts/b Avg       4044152
# Bwd Blk Rate Avg     4044152
# Subflow Fwd Pkts           0
# Subflow Fwd Byts      298303
# Subflow Bwd Pkts      330952
# Subflow Bwd Byts      573652
# Init Fwd Win Byts      40810
# Init Bwd Win Byts     109021
# Fwd Act Data Pkts     727848
# Fwd Seg Size Min     1772876
# Active Mean          3584997
# Active Std           3832748
# Active Max           3584997
# Active Min           3584997
# Idle Mean            3575410
# Idle Std             3826378
# Idle Max             3575410
# Idle Min             3575410
# Label                2273097
# dtype: int64

# %%
pd.set_option('display.max_rows', None)

# 2. Calculate the percentage of zeros
# (df_test_new == 0).mean() gives the proportion, * 100 gives the %
zero_percentage = (df == 0).mean() * 100

# 3. Print the result (sorted descending so you see the "emptiest" columns first)
print(zero_percentage)
# Out:
# Flow ID                0.000000
# Src IP                 0.000000
# Src Port               0.101480
# Dst IP                 0.000000
# Dst Port               0.101480
# Protocol               0.101480
# Timestamp              0.000000
# Flow Duration          0.060507
# Tot Fwd Pkts           0.000000
# Tot Bwd Pkts           8.183471
# TotLen Fwd Pkts        7.376157
# TotLen Bwd Pkts       14.184729
# Fwd Pkt Len Max        7.376157
# Fwd Pkt Len Min       22.356751
# Fwd Pkt Len Mean       7.376157
# Fwd Pkt Len Std       82.236227
# Bwd Pkt Len Max       14.184729
# Bwd Pkt Len Min       25.928798
# Bwd Pkt Len Mean      14.184729
# Bwd Pkt Len Std       86.427563
# Flow Byts/s            7.082523
# Flow Pkts/s            0.000000
# Flow IAT Mean          0.060507
# Flow IAT Std          20.785495
# Flow IAT Max           0.060482
# Flow IAT Min           4.333393
# Fwd IAT Tot           15.191664
# Fwd IAT Mean          15.191664
# Fwd IAT Std           41.035055
# Fwd IAT Max           15.191664
# Fwd IAT Min           18.374087
# Bwd IAT Total         67.372591
# Bwd IAT Mean          67.372591
# Bwd IAT Std           86.248019
# Bwd IAT Max           67.372591
# Bwd IAT Min           67.625673
# Fwd PSH Flags         96.915002
# Bwd PSH Flags        100.000000
# Fwd URG Flags         99.992211
# Bwd URG Flags        100.000000
# Fwd Header Len         0.103013
# Bwd Header Len         8.246352
# Fwd Packets/s          0.063351
# Bwd Packets/s          8.223850
# Pkt Len Min           22.778644
# Pkt Len Max            7.093255
# Pkt Len Mean           7.093255
# Pkt Len Std           58.264032
# Pkt Len Var           58.264032
# FIN Flag Cnt          98.981542
# SYN Flag Cnt          96.914755
# RST Flag Cnt          99.983037
# PSH Flag Cnt          85.498122
# ACK Flag Cnt          83.871823
# URG Flag Cnt          93.482144
# CWE Flag Count        99.992211
# ECE Flag Cnt          99.982963
# Down/Up Ratio         61.980905
# Pkt Size Avg           7.093255
# Fwd Seg Size Avg       7.376157
# Bwd Seg Size Avg      14.184729
# Fwd Byts/b Avg       100.000000
# Fwd Pkts/b Avg       100.000000
# Fwd Blk Rate Avg     100.000000
# Bwd Byts/b Avg       100.000000
# Bwd Pkts/b Avg       100.000000
# Bwd Blk Rate Avg     100.000000
# Subflow Fwd Pkts       0.000000
# Subflow Fwd Byts       7.376157
# Subflow Bwd Pkts       8.183471
# Subflow Bwd Byts      14.184729
# Init Fwd Win Byts      1.009111
# Init Bwd Win Byts      2.695769
# Fwd Act Data Pkts     17.997543
# Fwd Seg Size Min      43.838016
# Active Mean           88.646446
# Active Std            94.772600
# Active Max            88.646446
# Active Min            88.646446
# Idle Mean             88.409387
# Idle Std              94.615089
# Idle Max              88.409387
# Idle Min              88.409387
# Label                 56.207012
# dtype: float64
