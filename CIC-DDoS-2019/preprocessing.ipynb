# %%
import pandas as pd

# %%
df = pd.read_csv('Benign_Traffic_CIC2017.csv')

# %%
df.duplicated().sum()
# Out:
# np.int64(202)

# %%
global_dups = df.duplicated().sum()

label_dups = df.groupby("Label").apply(
    lambda x: x.duplicated().sum()
).sum()

print(global_dups, label_dups)
# Out:
# 202 202
# C:\Users\Cloud-2\AppData\Local\Temp\ipykernel_9828\3639644098.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   label_dups = df.groupby("Label").apply(

# %%
print(df["Label"].isna().sum())
# Out:
# 0

# %%
# Use dropna=False to include the rows with missing labels
df.groupby("Label", dropna=False).apply(lambda x: x.duplicated().sum())
# Out:
# C:\Users\Cloud-2\AppData\Local\Temp\ipykernel_9828\2161749747.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("Label", dropna=False).apply(lambda x: x.duplicated().sum())
# Label
# BENIGN    202
# dtype: int64

# %%
df.shape
# Out:
# (2273097, 84)

# %%
rows_with_nan = df.isna().any(axis=1).sum()

print(f"Total rows with at least one NaN: {rows_with_nan}")
# Out:
# Total rows with at least one NaN: 409

# %%
total_nans = df.isna().sum().sum()
print(f"Total missing values in DF: {total_nans}")
# Out:
# Total missing values in DF: 409

# %%
# This will show only the columns that have at least one NaN
print(df.columns[df.isna().any()].tolist())
# Out:
# ['Flow Byts/s']

# %%
df['Flow Byts/s'].isna().sum()
# Out:
# np.int64(409)

# %%
# 1. Filter the dataframe for only rows where Flow Bytes/s is NaN
nan_data = df[df['Flow Byts/s'].isna()]

# 2. Count the labels within that subset
distribution = nan_data['Label'].value_counts()

print("Distribution of NaNs per Label:")
print(distribution)

# 3. Optional: See the percentage of each label that is "broken"
total_per_label = df['Label'].value_counts()
nan_percentage = (distribution / total_per_label) * 100
print("\nPercentage of each Label that has NaNs:")
print(nan_percentage.dropna())
# Out:
# Distribution of NaNs per Label:
# Label
# BENIGN    409
# Name: count, dtype: int64
#
# Percentage of each Label that has NaNs:
# Label
# BENIGN    0.017993
# Name: count, dtype: float64

# %%
df['Label'].value_counts()
# Out:
# Label
# BENIGN    2273097
# Name: count, dtype: int64

# %%
# 1. Select only the columns that contain text/objects
string_columns = df.select_dtypes(include=['object']).columns

# 2. Check if the stripped string is empty
# .str.strip() removes spaces; .eq('') checks if it is then empty
blanks_mask = df[string_columns].apply(lambda x: x.str.strip().eq('')).any(axis=1)

total_blank_rows = blanks_mask.sum()
print(f"Total rows with at least one blank entry: {total_blank_rows}")
# Out:
# Total rows with at least one blank entry: 0

# %%
import numpy as np

# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Total number of infinite values
total_inf = np.isinf(numeric_df).values.sum()

print(f"Total infinite entries: {total_inf}")
# Out:
# Total infinite entries: 3145

# %%
# Check if any value in a row is infinite
inf_rows = np.isinf(numeric_df).any(axis=1).sum()

print(f"Total rows with at least one infinite value: {inf_rows}")
# Out:
# Total rows with at least one infinite value: 1777

# %%
import numpy as np

# Select only numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns

# Count infinite values (positive and negative) per column
inf_counts = np.isinf(df[numeric_cols]).sum()

# Display only columns that have at least one infinite value
print("Infinite values per column:")
print(inf_counts[inf_counts > 0])
# Out:
# Infinite values per column:
# Flow Byts/s    1368
# Flow Pkts/s    1777
# dtype: int64

# %%
# 1. Create a boolean mask for any row that has at least one infinite value
inf_rows_mask = np.isinf(df[numeric_cols]).any(axis=1)

# 2. Filter the dataframe using that mask and count the Labels
inf_label_dist = df[inf_rows_mask]['Label'].value_counts()

print("\nDistribution of Infinite entries per Label:")
print(inf_label_dist)
# Out:
# Distribution of Infinite entries per Label:
# Label
# BENIGN    1777
# Name: count, dtype: int64

# %%
total_inf_cells = np.isinf(df[numeric_cols]).values.sum()
total_rows_with_inf = inf_rows_mask.sum()

print(f"\nTotal infinite cells in dataset: {total_inf_cells}")
print(f"Total rows affected by infinity: {total_rows_with_inf}")
# Out:
# Total infinite cells in dataset: 3145
# Total rows affected by infinity: 1777

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
rows_with_nan = df.isna().any(axis=1).sum()

print(f"Total rows with at least one NaN: {rows_with_nan}")
# Out:
# Total rows with at least one NaN: 1777

# %%
total_nans = df.isna().sum().sum()
print(f"Total missing values in DF: {total_nans}")
# Out:
# Total missing values in DF: 3554

# %%
# This will show only the columns that have at least one NaN
print(df.columns[df.isna().any()].tolist())
# Out:
# ['Flow Byts/s', 'Flow Pkts/s']

# %%
df.describe()
# Out:
#            Src Port      Dst Port      Protocol  Flow Duration  Tot Fwd Pkts  \
# count  2.273097e+06  2.273097e+06  2.273097e+06   2.273097e+06  2.273097e+06
# mean   3.972058e+04  9.419545e+03  1.083229e+01   1.122082e+07  1.065417e+01
# std    2.410501e+04  1.975513e+04  5.466262e+00   3.012316e+07  8.365356e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  -1.300000e+01  1.000000e+00
# 25%    1.161100e+04  5.300000e+01  6.000000e+00   1.740000e+02  2.000000e+00
# 50%    5.148600e+04  8.000000e+01  6.000000e+00   3.099600e+04  2.000000e+00
# 75%    5.942300e+04  4.430000e+02  1.700000e+01   4.521860e+05  4.000000e+00
# max    6.553500e+04  6.553500e+04  1.700000e+01   1.200000e+08  2.197590e+05
#
#        Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# count  2.273097e+06     2.273097e+06     2.273097e+06     2.273097e+06
# mean   1.213864e+01     6.355369e+02     1.884871e+04     2.303862e+02
# std    1.112989e+03     1.063409e+04     2.525410e+06     7.913701e+02
# min    0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%    1.000000e+00     1.200000e+01     4.000000e+00     6.000000e+00
# 50%    2.000000e+00     6.600000e+01     1.300000e+02     4.000000e+01
# 75%    2.000000e+00     1.600000e+02     3.320000e+02     6.500000e+01
# max    2.919220e+05     1.290000e+07     6.554530e+08     2.482000e+04
#
#        Fwd Pkt Len Min  ...  Fwd Act Data Pkts  Fwd Seg Size Min  \
# count     2.273097e+06  ...       2.273097e+06      2.273097e+06
# mean      2.279337e+01  ...       6.361345e+00     -3.421018e+03
# std       6.336969e+01  ...       7.101772e+02      1.210783e+06
# min       0.000000e+00  ...       0.000000e+00     -5.368707e+08
# 25%       0.000000e+00  ...       0.000000e+00      2.000000e+01
# 50%       6.000000e+00  ...       1.000000e+00      2.000000e+01
# 75%       4.000000e+01  ...       2.000000e+00      3.200000e+01
# max       2.325000e+03  ...       2.135570e+05      1.380000e+02
#
#         Active Mean    Active Std    Active Max    Active Min     Idle Mean  \
# count  2.273097e+06  2.273097e+06  2.273097e+06  2.273097e+06  2.273097e+06
# mean   7.639679e+04  4.647617e+04  1.622499e+05  5.087366e+04  3.745967e+06
# std    6.383500e+05  4.077516e+05  1.074298e+06  5.583335e+05  1.349130e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.100000e+08  7.420000e+07  1.100000e+08  1.100000e+08  1.200000e+08
#
#            Idle Std      Idle Max      Idle Min
# count  2.273097e+06  2.273097e+06  2.273097e+06
# mean   2.603709e+05  3.937925e+06  3.515161e+06
# std    2.974647e+06  1.411090e+07  1.319937e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00
# max    7.690000e+07  1.200000e+08  1.200000e+08
#
# [8 rows x 79 columns]

# %%
# Save the cleaned DataFrame back to your file
df.to_csv('Benign_Traffic_CIC2017.csv', index=False)

# %%
pd.set_option('display.max_rows', None)

# 2. Run your zero-count check again
# Replace 'df' with the name of your dataframe (e.g., X_normalized or data)
zero_counts = (df == 0).sum()

# 3. Print the result
print(zero_counts)
# Out:
# Flow ID                    0
# Src IP                     0
# Src Port                1690
# Dst IP                     0
# Dst Port                1690
# Protocol                1690
# Timestamp                  0
# Flow Duration           1777
# Tot Fwd Pkts               0
# Tot Bwd Pkts          330952
# TotLen Fwd Pkts       290107
# TotLen Bwd Pkts       565441
# Fwd Pkt Len Max       290107
# Fwd Pkt Len Min       895704
# Fwd Pkt Len Mean      290107
# Fwd Pkt Len Std      1556011
# Bwd Pkt Len Max       565441
# Bwd Pkt Len Min      1040389
# Bwd Pkt Len Mean      565441
# Bwd Pkt Len Std      1724207
# Flow Byts/s           278257
# Flow Pkts/s                0
# Flow IAT Mean           1777
# Flow IAT Std          774518
# Flow IAT Max            1776
# Flow IAT Min           52606
# Fwd IAT Tot           548329
# Fwd IAT Mean          548329
# Fwd IAT Std          1539029
# Fwd IAT Max           548329
# Fwd IAT Min           559537
# Bwd IAT Total         953595
# Bwd IAT Mean          953595
# Bwd IAT Std          1716946
# Bwd IAT Max           953595
# Bwd IAT Min           963830
# Fwd PSH Flags        2148335
# Bwd PSH Flags        2273097
# Fwd URG Flags        2272782
# Bwd URG Flags        2273097
# Fwd Header Len          1752
# Bwd Header Len        331081
# Fwd Packets/s           1892
# Bwd Packets/s         331915
# Pkt Len Min           912754
# Pkt Len Max           278666
# Pkt Len Mean          278666
# Pkt Len Std           586823
# Pkt Len Var           586823
# FIN Flag Cnt         2231909
# SYN Flag Cnt         2148335
# RST Flag Cnt         2272411
# PSH Flag Cnt         1686619
# ACK Flag Cnt         1620849
# URG Flag Cnt         2009505
# CWE Flag Count       2272782
# ECE Flag Cnt         2272408
# Down/Up Ratio         801064
# Pkt Size Avg          278666
# Fwd Seg Size Avg      290107
# Bwd Seg Size Avg      565441
# Fwd Byts/b Avg       2273097
# Fwd Pkts/b Avg       2273097
# Fwd Blk Rate Avg     2273097
# Bwd Byts/b Avg       2273097
# Bwd Pkts/b Avg       2273097
# Bwd Blk Rate Avg     2273097
# Subflow Fwd Pkts           0
# Subflow Fwd Byts      290107
# Subflow Bwd Pkts      330952
# Subflow Bwd Byts      565441
# Init Fwd Win Byts      40810
# Init Bwd Win Byts     109021
# Fwd Act Data Pkts     719652
# Fwd Seg Size Min        1821
# Active Mean          1915633
# Active Std           2069713
# Active Max           1915633
# Active Min           1915633
# Idle Mean            1914418
# Idle Std             2064006
# Idle Max             1914418
# Idle Min             1914418
# Label                      0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)

# 2. Calculate the percentage of zeros
# (df_test_new == 0).mean() gives the proportion, * 100 gives the %
zero_percentage = (df == 0).mean() * 100

# 3. Print the result (sorted descending so you see the "emptiest" columns first)
print(zero_percentage)
# Out:
# Flow ID                0.000000
# Src IP                 0.000000
# Src Port               0.074348
# Dst IP                 0.000000
# Dst Port               0.074348
# Protocol               0.074348
# Timestamp              0.000000
# Flow Duration          0.078175
# Tot Fwd Pkts           0.000000
# Tot Bwd Pkts          14.559519
# TotLen Fwd Pkts       12.762632
# TotLen Bwd Pkts       24.875357
# Fwd Pkt Len Max       12.762632
# Fwd Pkt Len Min       39.404566
# Fwd Pkt Len Mean      12.762632
# Fwd Pkt Len Std       68.453348
# Bwd Pkt Len Max       24.875357
# Bwd Pkt Len Min       45.769670
# Bwd Pkt Len Mean      24.875357
# Bwd Pkt Len Std       75.852768
# Flow Byts/s           12.241317
# Flow Pkts/s            0.000000
# Flow IAT Mean          0.078175
# Flow IAT Std          34.073249
# Flow IAT Max           0.078131
# Flow IAT Min           2.314288
# Fwd IAT Tot           24.122552
# Fwd IAT Mean          24.122552
# Fwd IAT Std           67.706262
# Fwd IAT Max           24.122552
# Fwd IAT Min           24.615624
# Bwd IAT Total         41.951355
# Bwd IAT Mean          41.951355
# Bwd IAT Std           75.533336
# Bwd IAT Max           41.951355
# Bwd IAT Min           42.401622
# Fwd PSH Flags         94.511365
# Bwd PSH Flags        100.000000
# Fwd URG Flags         99.986142
# Bwd URG Flags        100.000000
# Fwd Header Len         0.077075
# Bwd Header Len        14.565195
# Fwd Packets/s          0.083234
# Bwd Packets/s         14.601885
# Pkt Len Min           40.154644
# Pkt Len Max           12.259310
# Pkt Len Mean          12.259310
# Pkt Len Std           25.816012
# Pkt Len Var           25.816012
# FIN Flag Cnt          98.188023
# SYN Flag Cnt          94.511365
# RST Flag Cnt          99.969821
# PSH Flag Cnt          74.199165
# ACK Flag Cnt          71.305756
# URG Flag Cnt          88.403838
# CWE Flag Count        99.986142
# ECE Flag Cnt          99.969689
# Down/Up Ratio         35.241083
# Pkt Size Avg          12.259310
# Fwd Seg Size Avg      12.762632
# Bwd Seg Size Avg      24.875357
# Fwd Byts/b Avg       100.000000
# Fwd Pkts/b Avg       100.000000
# Fwd Blk Rate Avg     100.000000
# Bwd Byts/b Avg       100.000000
# Bwd Pkts/b Avg       100.000000
# Bwd Blk Rate Avg     100.000000
# Subflow Fwd Pkts       0.000000
# Subflow Fwd Byts      12.762632
# Subflow Bwd Pkts      14.559519
# Subflow Bwd Byts      24.875357
# Init Fwd Win Byts      1.795348
# Init Bwd Win Byts      4.796144
# Fwd Act Data Pkts     31.659538
# Fwd Seg Size Min       0.080111
# Active Mean           84.274142
# Active Std            91.052560
# Active Max            84.274142
# Active Min            84.274142
# Idle Mean             84.220691
# Idle Std              90.801492
# Idle Max              84.220691
# Idle Min              84.220691
# Label                  0.000000
# dtype: float64
