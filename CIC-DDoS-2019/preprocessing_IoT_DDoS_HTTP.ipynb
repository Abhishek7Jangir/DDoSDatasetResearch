# %%
import pandas as pd

# %%
df = pd.read_csv('IoT_Dataset_HTTP_DDoS.csv')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
global_dups = df.duplicated().sum()

label_dups = df.groupby("Label").apply(
    lambda x: x.duplicated().sum()
).sum()

print(global_dups, label_dups)
# Out:
# 0 0
# C:\Users\Cloud-2\AppData\Local\Temp\ipykernel_8160\3639644098.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   label_dups = df.groupby("Label").apply(

# %%
print(df["Label"].isna().sum())
# Out:
# 0

# %%
df.shape
# Out:
# (35147, 84)

# %%
rows_with_nan = df.isna().any(axis=1).sum()

print(f"Total rows with at least one NaN: {rows_with_nan}")
# Out:
# Total rows with at least one NaN: 14

# %%
print(df.isna().sum())
# Out:
# Flow ID      0
# Src IP       0
# Src Port     0
# Dst IP       0
# Dst Port     0
#             ..
# Idle Mean    0
# Idle Std     0
# Idle Max     0
# Idle Min     0
# Label        0
# Length: 84, dtype: int64

# %%
total_nans = df.isna().sum().sum()
print(f"Total missing values in DF: {total_nans}")
# Out:
# Total missing values in DF: 14

# %%
# This will show only the columns that have at least one NaN
print(df.columns[df.isna().any()].tolist())
# Out:
# ['Flow Byts/s']

# %%
df['Flow Byts/s'].isna().sum()
# Out:
# np.int64(14)

# %%
# 1. Filter the dataframe for only rows where Flow Bytes/s is NaN
nan_data = df[df['Flow Byts/s'].isna()]

# 2. Count the labels within that subset
distribution = nan_data['Label'].value_counts()

print("Distribution of NaNs per Label:")
print(distribution)

# 3. Optional: See the percentage of each label that is "broken"
total_per_label = df['Label'].value_counts()
nan_percentage = (distribution / total_per_label) * 100
print("\nPercentage of each Label that has NaNs:")
print(nan_percentage.dropna())
# Out:
# Distribution of NaNs per Label:
# Label
# No Label    14
# Name: count, dtype: int64
#
# Percentage of each Label that has NaNs:
# Label
# No Label    0.039833
# Name: count, dtype: float64

# %%
# 1. Select only the columns that contain text/objects
string_columns = df.select_dtypes(include=['object']).columns

# 2. Check if the stripped string is empty
# .str.strip() removes spaces; .eq('') checks if it is then empty
blanks_mask = df[string_columns].apply(lambda x: x.str.strip().eq('')).any(axis=1)

total_blank_rows = blanks_mask.sum()
print(f"Total rows with at least one blank entry: {total_blank_rows}")
# Out:
# Total rows with at least one blank entry: 0

# %%
import numpy as np

# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Total number of infinite values
total_inf = np.isinf(numeric_df).values.sum()

print(f"Total infinite entries: {total_inf}")
# Out:
# Total infinite entries: 14

# %%
# Check if any value in a row is infinite
inf_rows = np.isinf(numeric_df).any(axis=1).sum()

print(f"Total rows with at least one infinite value: {inf_rows}")
# Out:
# Total rows with at least one infinite value: 14

# %%
import numpy as np

# Select only numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns

# Count infinite values (positive and negative) per column
inf_counts = np.isinf(df[numeric_cols]).sum()

# Display only columns that have at least one infinite value
print("Infinite values per column:")
print(inf_counts[inf_counts > 0])
# Out:
# Infinite values per column:
# Flow Pkts/s    14
# dtype: int64

# %%
# 1. Create a boolean mask for any row that has at least one infinite value
inf_rows_mask = np.isinf(df[numeric_cols]).any(axis=1)

# 2. Filter the dataframe using that mask and count the Labels
inf_label_dist = df[inf_rows_mask]['Label'].value_counts()

print("\nDistribution of Infinite entries per Label:")
print(inf_label_dist)
# Out:
# Distribution of Infinite entries per Label:
# Label
# No Label    14
# Name: count, dtype: int64

# %%
total_inf_cells = np.isinf(df[numeric_cols]).values.sum()
total_rows_with_inf = inf_rows_mask.sum()

print(f"\nTotal infinite cells in dataset: {total_inf_cells}")
print(f"Total rows affected by infinity: {total_rows_with_inf}")
# Out:
# Total infinite cells in dataset: 14
# Total rows affected by infinity: 14

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
rows_with_nan = df.isna().any(axis=1).sum()

print(f"Total rows with at least one NaN: {rows_with_nan}")
# Out:
# Total rows with at least one NaN: 14

# %%
total_nans = df.isna().sum().sum()
print(f"Total missing values in DF: {total_nans}")
# Out:
# Total missing values in DF: 28

# %%
# This will show only the columns that have at least one NaN
print(df.columns[df.isna().any()].tolist())
# Out:
# ['Flow Byts/s', 'Flow Pkts/s']

# %%
# 1. Filter the dataframe for only rows where Flow Bytes/s is NaN
nan_data = df[df['Flow Byts/s'].isna()]

# 2. Count the labels within that subset
distribution = nan_data['Label'].value_counts()

print("Distribution of NaNs per Label:")
print(distribution)

# 3. Optional: See the percentage of each label that is "broken"
total_per_label = df['Label'].value_counts()
nan_percentage = (distribution / total_per_label) * 100
print("\nPercentage of each Label that has NaNs:")
print(nan_percentage.dropna())
# Out:
# Distribution of NaNs per Label:
# Label
# No Label    14
# Name: count, dtype: int64
#
# Percentage of each Label that has NaNs:
# Label
# No Label    0.039833
# Name: count, dtype: float64

# %%
df.dropna(inplace=True)

# %%
total_nans = df.isna().sum().sum()
print(f"Total missing values in DF: {total_nans}")
# Out:
# Total missing values in DF: 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#            Src Port      Dst Port      Protocol  Flow Duration  Tot Fwd Pkts  \
# count  35133.000000  35133.000000  35133.000000   3.513300e+04  35133.000000
# mean   46904.402755   1243.625224      6.032505   2.507436e+07     38.889904
# std    11460.658170   7380.858270      0.606731   2.474218e+07    539.699783
# min        0.000000      0.000000      0.000000   1.000000e+00      0.000000
# 25%    41436.000000     80.000000      6.000000   9.413399e+06      1.000000
# 50%    47708.000000     80.000000      6.000000   1.632523e+07      3.000000
# 75%    56096.000000     80.000000      6.000000   3.345160e+07      3.000000
# max    64553.000000  60998.000000     17.000000   1.199999e+08   9598.000000
#
#        Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# count  35133.000000     3.513300e+04     3.513300e+04     35133.000000
# mean      16.553411     2.795480e+04     1.280598e+04       249.333476
# std      350.320128     4.629332e+05     3.243525e+05       245.910302
# min        1.000000     0.000000e+00     0.000000e+00         0.000000
# 25%        1.000000     0.000000e+00     0.000000e+00         0.000000
# 50%        4.000000     3.310000e+02     4.940000e+02       328.000000
# 75%        5.000000     4.440000e+02     1.124000e+03       437.000000
# max     9599.000000     9.151774e+06     9.152933e+06      1472.000000
#
#        Fwd Pkt Len Min  ...  Fwd Act Data Pkts  Fwd Seg Size Min  \
# count     35133.000000  ...       35133.000000           35133.0
# mean          5.334586  ...          37.273105               0.0
# std          68.537319  ...         539.807596               0.0
# min           0.000000  ...           0.000000               0.0
# 25%           0.000000  ...           0.000000               0.0
# 50%           0.000000  ...           1.000000               0.0
# 75%           0.000000  ...           1.000000               0.0
# max        1138.000000  ...        9598.000000               0.0
#
#         Active Mean    Active Std    Active Max    Active Min     Idle Mean  \
# count  3.513300e+04  3.513300e+04  3.513300e+04  3.513300e+04  3.513300e+04
# mean   7.342527e+04  2.435790e+04  9.911408e+04  5.633818e+04  1.901268e+07
# std    8.983445e+05  4.194844e+05  1.134987e+06  8.381009e+05  2.508709e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  8.992069e+06
# 75%    9.300000e+01  0.000000e+00  9.300000e+01  9.200000e+01  2.075395e+07
# max    9.708721e+07  1.457036e+07  9.708721e+07  9.708721e+07  1.198053e+08
#
#            Idle Std      Idle Max      Idle Min
# count  3.513300e+04  3.513300e+04  3.513300e+04
# mean   4.427428e+04  1.905788e+07  1.897926e+07
# std    6.165087e+05  2.508839e+07  2.509893e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  8.997357e+06  8.936631e+06
# 75%    0.000000e+00  2.075486e+07  2.075388e+07
# max    2.254007e+07  1.198053e+08  1.198053e+08
#
# [8 rows x 79 columns]

# %%
df.shape
# Out:
# (35133, 84)

# %%
# Save the cleaned DataFrame back to your file
df.to_csv('IoT_Dataset_HTTP_DDoS.csv', index=False)

# %%
pd.set_option('display.max_rows', None)

# 2. Run your zero-count check again
# Replace 'df' with the name of your dataframe (e.g., X_normalized or data)
zero_counts = (df == 0).sum()

# 3. Print the result
print(zero_counts)
# Out:
# Flow ID                  0
# Src IP                   0
# Src Port                30
# Dst IP                   0
# Dst Port                30
# Protocol                 4
# Timestamp                0
# Flow Duration            0
# Tot Fwd Pkts           601
# Tot Bwd Pkts             0
# TotLen Fwd Pkts      15602
# TotLen Bwd Pkts      15859
# Fwd Pkt Len Max      15602
# Fwd Pkt Len Min      34807
# Fwd Pkt Len Mean     15602
# Fwd Pkt Len Std      15776
# Bwd Pkt Len Max      15859
# Bwd Pkt Len Min      34862
# Bwd Pkt Len Mean     15859
# Bwd Pkt Len Std      16058
# Flow Byts/s          15318
# Flow Pkts/s              0
# Flow IAT Mean            0
# Flow IAT Std         14968
# Flow IAT Max             0
# Flow IAT Min            29
# Fwd IAT Tot          15715
# Fwd IAT Mean         15715
# Fwd IAT Std          15857
# Fwd IAT Max          15715
# Fwd IAT Min          15723
# Bwd IAT Tot          14948
# Bwd IAT Mean         14948
# Bwd IAT Std          15432
# Bwd IAT Max          14948
# Bwd IAT Min          14958
# Fwd PSH Flags        35133
# Bwd PSH Flags        34854
# Fwd URG Flags        35133
# Bwd URG Flags        35133
# Fwd Header Len         605
# Bwd Header Len           4
# Fwd Pkts/s             601
# Bwd Pkts/s               0
# Pkt Len Min          34923
# Pkt Len Max          15318
# Pkt Len Mean         15318
# Pkt Len Std          15376
# Pkt Len Var          15376
# FIN Flag Cnt         34692
# SYN Flag Cnt         15944
# RST Flag Cnt         35080
# PSH Flag Cnt         34854
# ACK Flag Cnt         19421
# URG Flag Cnt         35133
# CWE Flag Count       35133
# ECE Flag Cnt         35133
# Down/Up Ratio         1497
# Pkt Size Avg         15318
# Fwd Seg Size Avg     15602
# Bwd Seg Size Avg     15859
# Fwd Byts/b Avg       35133
# Fwd Pkts/b Avg       35133
# Fwd Blk Rate Avg     35133
# Bwd Byts/b Avg       35133
# Bwd Pkts/b Avg       35133
# Bwd Blk Rate Avg     35133
# Subflow Fwd Pkts       601
# Subflow Fwd Byts     15602
# Subflow Bwd Pkts         0
# Subflow Bwd Byts     15859
# Init Fwd Win Byts        0
# Init Bwd Win Byts      250
# Fwd Act Data Pkts    15602
# Fwd Seg Size Min     35133
# Active Mean          22220
# Active Std           34934
# Active Max           22220
# Active Min           22220
# Idle Mean             9706
# Idle Std             34888
# Idle Max              9706
# Idle Min              9706
# Label                    0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)

# 2. Calculate the percentage of zeros
# (df_test_new == 0).mean() gives the proportion, * 100 gives the %
zero_percentage = (df == 0).mean() * 100

# 3. Print the result (sorted descending so you see the "emptiest" columns first)
print(zero_percentage)
# Out:
# Flow ID                0.000000
# Src IP                 0.000000
# Src Port               0.085390
# Dst IP                 0.000000
# Dst Port               0.085390
# Protocol               0.011385
# Timestamp              0.000000
# Flow Duration          0.000000
# Tot Fwd Pkts           1.710642
# Tot Bwd Pkts           0.000000
# TotLen Fwd Pkts       44.408391
# TotLen Bwd Pkts       45.139897
# Fwd Pkt Len Max       44.408391
# Fwd Pkt Len Min       99.072097
# Fwd Pkt Len Mean      44.408391
# Fwd Pkt Len Std       44.903652
# Bwd Pkt Len Max       45.139897
# Bwd Pkt Len Min       99.228645
# Bwd Pkt Len Mean      45.139897
# Bwd Pkt Len Std       45.706316
# Flow Byts/s           43.600034
# Flow Pkts/s            0.000000
# Flow IAT Mean          0.000000
# Flow IAT Std          42.603820
# Flow IAT Max           0.000000
# Flow IAT Min           0.082543
# Fwd IAT Tot           44.730026
# Fwd IAT Mean          44.730026
# Fwd IAT Std           45.134204
# Fwd IAT Max           44.730026
# Fwd IAT Min           44.752797
# Bwd IAT Tot           42.546893
# Bwd IAT Mean          42.546893
# Bwd IAT Std           43.924515
# Bwd IAT Max           42.546893
# Bwd IAT Min           42.575357
# Fwd PSH Flags        100.000000
# Bwd PSH Flags         99.205875
# Fwd URG Flags        100.000000
# Bwd URG Flags        100.000000
# Fwd Header Len         1.722028
# Bwd Header Len         0.011385
# Fwd Pkts/s             1.710642
# Bwd Pkts/s             0.000000
# Pkt Len Min           99.402271
# Pkt Len Max           43.600034
# Pkt Len Mean          43.600034
# Pkt Len Std           43.765121
# Pkt Len Var           43.765121
# FIN Flag Cnt          98.744770
# SYN Flag Cnt          45.381835
# RST Flag Cnt          99.849145
# PSH Flag Cnt          99.205875
# ACK Flag Cnt          55.278513
# URG Flag Cnt         100.000000
# CWE Flag Count       100.000000
# ECE Flag Cnt         100.000000
# Down/Up Ratio          4.260951
# Pkt Size Avg          43.600034
# Fwd Seg Size Avg      44.408391
# Bwd Seg Size Avg      45.139897
# Fwd Byts/b Avg       100.000000
# Fwd Pkts/b Avg       100.000000
# Fwd Blk Rate Avg     100.000000
# Bwd Byts/b Avg       100.000000
# Bwd Pkts/b Avg       100.000000
# Bwd Blk Rate Avg     100.000000
# Subflow Fwd Pkts       1.710642
# Subflow Fwd Byts      44.408391
# Subflow Bwd Pkts       0.000000
# Subflow Bwd Byts      45.139897
# Init Fwd Win Byts      0.000000
# Init Bwd Win Byts      0.711582
# Fwd Act Data Pkts     44.408391
# Fwd Seg Size Min     100.000000
# Active Mean           63.245382
# Active Std            99.433581
# Active Max            63.245382
# Active Min            63.245382
# Idle Mean             27.626448
# Idle Std              99.302650
# Idle Max              27.626448
# Idle Min              27.626448
# Label                  0.000000
# dtype: float64
