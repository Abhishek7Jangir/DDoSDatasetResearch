# %%
import pandas as pd

# %%
df = pd.read_csv('Bot_IoT_DDoS.csv')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df["Label"].isna().sum())
# Out:
# 0

# %%
df.shape
# Out:
# (38049077, 84)

# %%
rows_with_nan = df.isna().any(axis=1).sum()

print(f"Total rows with at least one NaN: {rows_with_nan}")
# Out:
# Total rows with at least one NaN: 14

# %%
total_nans = df.isna().sum().sum()
print(f"Total missing values in DF: {total_nans}")
# Out:
# Total missing values in DF: 14

# %%
# This will show only the columns that have at least one NaN
print(df.columns[df.isna().any()].tolist())
# Out:
# ['Flow Byts/s']

# %%
# 1. Filter the dataframe for only rows where Flow Bytes/s is NaN
nan_data = df[df['Flow Byts/s'].isna()]

# 2. Count the labels within that subset
distribution = nan_data['Label'].value_counts()

print("Distribution of NaNs per Label:")
print(distribution)

# 3. Optional: See the percentage of each label that is "broken"
total_per_label = df['Label'].value_counts()
nan_percentage = (distribution / total_per_label) * 100
print("\nPercentage of each Label that has NaNs:")
print(nan_percentage.dropna())
# Out:
# Distribution of NaNs per Label:
# Label
# No Label    14
# Name: count, dtype: int64
#
# Percentage of each Label that has NaNs:
# Label
# No Label    0.000037
# Name: count, dtype: float64

# %%
df['Label'] = 1

# %%
df['Label'].value_counts()
# Out:
# Label
# 1    38049077
# Name: count, dtype: int64

# %%
# 1. Select only the columns that contain text/objects
string_columns = df.select_dtypes(include=['object']).columns

# 2. Check if the stripped string is empty
# .str.strip() removes spaces; .eq('') checks if it is then empty
blanks_mask = df[string_columns].apply(lambda x: x.str.strip().eq('')).any(axis=1)

total_blank_rows = blanks_mask.sum()
print(f"Total rows with at least one blank entry: {total_blank_rows}")
# Out:
# Total rows with at least one blank entry: 0

# %%
import numpy as np

# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Total number of infinite values
total_inf = np.isinf(numeric_df).values.sum()

print(f"Total infinite entries: {total_inf}")
# Out:
# Total infinite entries: 14

# %%
# Check if any value in a row is infinite
inf_rows = np.isinf(numeric_df).any(axis=1).sum()

print(f"Total rows with at least one infinite value: {inf_rows}")
# Out:
# Total rows with at least one infinite value: 14

# %%
import numpy as np

# Select only numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns

# Count infinite values (positive and negative) per column
inf_counts = np.isinf(df[numeric_cols]).sum()

# Display only columns that have at least one infinite value
print("Infinite values per column:")
print(inf_counts[inf_counts > 0])
# Out:
# Infinite values per column:
# Flow Pkts/s    14
# dtype: int64

# %%
# 1. Create a boolean mask for any row that has at least one infinite value
inf_rows_mask = np.isinf(df[numeric_cols]).any(axis=1)

# 2. Filter the dataframe using that mask and count the Labels
inf_label_dist = df[inf_rows_mask]['Label'].value_counts()

print("\nDistribution of Infinite entries per Label:")
print(inf_label_dist)
# Out:
# Distribution of Infinite entries per Label:
# Label
# 1    14
# Name: count, dtype: int64

# %%
total_inf_cells = np.isinf(df[numeric_cols]).values.sum()
total_rows_with_inf = inf_rows_mask.sum()

print(f"\nTotal infinite cells in dataset: {total_inf_cells}")
print(f"Total rows affected by infinity: {total_rows_with_inf}")
# Out:
# Total infinite cells in dataset: 14
# Total rows affected by infinity: 14

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
rows_with_nan = df.isna().any(axis=1).sum()

print(f"Total rows with at least one NaN: {rows_with_nan}")
# Out:
# Total rows with at least one NaN: 14

# %%
total_nans = df.isna().sum().sum()
print(f"Total missing values in DF: {total_nans}")
# Out:
# Total missing values in DF: 28

# %%
# This will show only the columns that have at least one NaN
print(df.columns[df.isna().any()].tolist())
# Out:
# ['Flow Byts/s', 'Flow Pkts/s']

# %%
# 1. Filter the dataframe for only rows where Flow Bytes/s is NaN
nan_data = df[df['Flow Byts/s'].isna()]

# 2. Count the labels within that subset
distribution = nan_data['Label'].value_counts()

print("Distribution of NaNs per Label:")
print(distribution)

# 3. Optional: See the percentage of each label that is "broken"
total_per_label = df['Label'].value_counts()
nan_percentage = (distribution / total_per_label) * 100
print("\nPercentage of each Label that has NaNs:")
print(nan_percentage.dropna())
# Out:
# Distribution of NaNs per Label:
# Label
# 1    14
# Name: count, dtype: int64
#
# Percentage of each Label that has NaNs:
# Label
# 1    0.000037
# Name: count, dtype: float64

# %%
df.describe()
# Out:
#            Src Port      Dst Port      Protocol  Flow Duration  Tot Fwd Pkts  \
# count  3.804908e+07  3.804908e+07  3.804908e+07   3.804908e+07  3.804908e+07
# mean   3.273960e+04  1.119447e+02  1.145765e+01   2.677087e+07  5.988535e+00
# std    1.893440e+04  1.181781e+03  5.499859e+00   1.813425e+07  2.193054e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00
# 25%    1.633100e+04  8.000000e+01  6.000000e+00   1.538579e+07  3.000000e+00
# 50%    3.275200e+04  8.000000e+01  6.000000e+00   2.060670e+07  5.000000e+00
# 75%    4.914100e+04  8.000000e+01  1.700000e+01   3.432871e+07  8.000000e+00
# max    6.553500e+04  6.548900e+04  1.700000e+01   1.200000e+08  9.598000e+03
#
#        Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# count  3.804908e+07     3.804908e+07     3.804908e+07     3.804908e+07
# mean   1.219461e+00     2.370843e+02     8.062919e+01     5.023621e+01
# std    1.410631e+01     1.864093e+04     1.305410e+04     5.132381e+01
# min    1.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%    1.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 50%    1.000000e+00     1.000000e+02     1.000000e+02     1.000000e+02
# 75%    1.000000e+00     3.000000e+02     1.000000e+02     1.000000e+02
# max    9.600000e+03     9.151774e+06     9.152933e+06     1.472000e+03
#
#        Fwd Pkt Len Min  ...  Fwd Seg Size Min   Active Mean    Active Std  \
# count     3.804908e+07  ...        38049077.0  3.804908e+07  3.804908e+07
# mean      4.170905e+01  ...               0.0  2.751766e+06  1.677655e+05
# std       4.936975e+01  ...               0.0  5.353721e+06  1.019058e+06
# min       0.000000e+00  ...               0.0  0.000000e+00  0.000000e+00
# 25%       0.000000e+00  ...               0.0  0.000000e+00  0.000000e+00
# 50%       0.000000e+00  ...               0.0  0.000000e+00  0.000000e+00
# 75%       1.000000e+02  ...               0.0  3.938750e+06  0.000000e+00
# max       1.138000e+03  ...               0.0  9.708721e+07  1.465103e+07
#
#          Active Max    Active Min     Idle Mean      Idle Std      Idle Max  \
# count  3.804908e+07  3.804908e+07  3.804908e+07  3.804908e+07  3.804908e+07
# mean   2.872421e+06  2.632396e+06  6.213837e+06  7.930230e+05  6.958111e+06
# std    5.524838e+06  5.279720e+06  5.534284e+06  1.478670e+06  6.072494e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  6.269315e+06  0.000000e+00  6.772668e+06
# 75%    4.129629e+06  3.654711e+06  8.409719e+06  9.881555e+05  1.028915e+07
# max    9.708721e+07  9.708721e+07  1.198053e+08  4.526457e+07  1.198053e+08
#
#            Idle Min       Label
# count  3.804908e+07  38049077.0
# mean   5.600940e+06         1.0
# std    5.306886e+06         0.0
# min    0.000000e+00         1.0
# 25%    0.000000e+00         1.0
# 50%    5.344110e+06         1.0
# 75%    6.978273e+06         1.0
# max    1.198053e+08         1.0
#
# [8 rows x 80 columns]

# %%
df.shape
# Out:
# (38049077, 84)

# %%
# Save the cleaned DataFrame back to your file
df.to_csv('Bot_IoT_DDoS.csv', index=False)

# %%
pd.set_option('display.max_rows', None)

# 2. Run your zero-count check again
# Replace 'df' with the name of your dataframe (e.g., X_normalized or data)
zero_counts = (df == 0).sum()

# 3. Print the result
print(zero_counts)
# Out:
# Flow ID                     0
# Src IP                      0
# Src Port                  844
# Dst IP                      0
# Dst Port                  267
# Protocol                   92
# Timestamp                   0
# Flow Duration              14
# Tot Fwd Pkts            99846
# Tot Bwd Pkts                0
# TotLen Fwd Pkts      19014560
# TotLen Bwd Pkts      18903368
# Fwd Pkt Len Max      19014560
# Fwd Pkt Len Min      22182806
# Fwd Pkt Len Mean     19014560
# Fwd Pkt Len Std      34879790
# Bwd Pkt Len Max      18903368
# Bwd Pkt Len Min      24424798
# Bwd Pkt Len Mean     18903368
# Bwd Pkt Len Std      32527244
# Flow Byts/s          18892906
# Flow Pkts/s                 0
# Flow IAT Mean              14
# Flow IAT Std          1113255
# Flow IAT Max               14
# Flow IAT Min               43
# Fwd IAT Tot           1208874
# Fwd IAT Mean          1208874
# Fwd IAT Std           3725402
# Fwd IAT Max           1208874
# Fwd IAT Min           1208882
# Bwd IAT Tot          32521351
# Bwd IAT Mean         32521351
# Bwd IAT Std          36772652
# Bwd IAT Max          32521351
# Bwd IAT Min          32521361
# Fwd PSH Flags        38049077
# Bwd PSH Flags        38048649
# Fwd URG Flags        38049077
# Bwd URG Flags        38049077
# Fwd Header Len          99938
# Bwd Header Len             92
# Fwd Pkts/s              99860
# Bwd Pkts/s                 14
# Pkt Len Min          24426609
# Pkt Len Max          18892920
# Pkt Len Mean         18892920
# Pkt Len Std          32514451
# Pkt Len Var          32514451
# FIN Flag Cnt         38048635
# SYN Flag Cnt         18906274
# RST Flag Cnt         38037529
# PSH Flag Cnt         38048649
# ACK Flag Cnt         37996564
# URG Flag Cnt         38049077
# CWE Flag Count       38049077
# ECE Flag Cnt         38049077
# Down/Up Ratio        36435121
# Pkt Size Avg         18892920
# Fwd Seg Size Avg     19014560
# Bwd Seg Size Avg     18903368
# Fwd Byts/b Avg       38049077
# Fwd Pkts/b Avg       38049077
# Fwd Blk Rate Avg     38049077
# Bwd Byts/b Avg       38049077
# Bwd Pkts/b Avg       38049077
# Bwd Blk Rate Avg     38049077
# Subflow Fwd Pkts        99846
# Subflow Fwd Byts     19014560
# Subflow Bwd Pkts            0
# Subflow Bwd Byts     18903368
# Init Fwd Win Byts           0
# Init Bwd Win Byts     2315414
# Fwd Act Data Pkts    19014560
# Fwd Seg Size Min     38049077
# Active Mean          23394602
# Active Std           35904914
# Active Max           23394602
# Active Min           23394602
# Idle Mean            12101712
# Idle Std             19890904
# Idle Max             12101712
# Idle Min             12101712
# Label                       0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)

# 2. Calculate the percentage of zeros
# (df_test_new == 0).mean() gives the proportion, * 100 gives the %
zero_percentage = (df == 0).mean() * 100

# 3. Print the result (sorted descending so you see the "emptiest" columns first)
print(zero_percentage)
# Out:
# Flow ID                0.000000
# Src IP                 0.000000
# Src Port               0.002218
# Dst IP                 0.000000
# Dst Port               0.000702
# Protocol               0.000242
# Timestamp              0.000000
# Flow Duration          0.000037
# Tot Fwd Pkts           0.262414
# Tot Bwd Pkts           0.000000
# TotLen Fwd Pkts       49.973775
# TotLen Bwd Pkts       49.681542
# Fwd Pkt Len Max       49.973775
# Fwd Pkt Len Min       58.300510
# Fwd Pkt Len Mean      49.973775
# Fwd Pkt Len Std       91.670529
# Bwd Pkt Len Max       49.681542
# Bwd Pkt Len Min       64.192879
# Bwd Pkt Len Mean      49.681542
# Bwd Pkt Len Std       85.487603
# Flow Byts/s           49.654045
# Flow Pkts/s            0.000000
# Flow IAT Mean          0.000037
# Flow IAT Std           2.925840
# Flow IAT Max           0.000037
# Flow IAT Min           0.000113
# Fwd IAT Tot            3.177144
# Fwd IAT Mean           3.177144
# Fwd IAT Std            9.791044
# Fwd IAT Max            3.177144
# Fwd IAT Min            3.177165
# Bwd IAT Tot           85.472115
# Bwd IAT Mean          85.472115
# Bwd IAT Std           96.645319
# Bwd IAT Max           85.472115
# Bwd IAT Min           85.472142
# Fwd PSH Flags        100.000000
# Bwd PSH Flags         99.998875
# Fwd URG Flags        100.000000
# Bwd URG Flags        100.000000
# Fwd Header Len         0.262656
# Bwd Header Len         0.000242
# Fwd Pkts/s             0.262451
# Bwd Pkts/s             0.000037
# Pkt Len Min           64.197639
# Pkt Len Max           49.654082
# Pkt Len Mean          49.654082
# Pkt Len Std           85.453981
# Pkt Len Var           85.453981
# FIN Flag Cnt          99.998838
# SYN Flag Cnt          49.689179
# RST Flag Cnt          99.969650
# PSH Flag Cnt          99.998875
# ACK Flag Cnt          99.861986
# URG Flag Cnt         100.000000
# CWE Flag Count       100.000000
# ECE Flag Cnt         100.000000
# Down/Up Ratio         95.758226
# Pkt Size Avg          49.654082
# Fwd Seg Size Avg      49.973775
# Bwd Seg Size Avg      49.681542
# Fwd Byts/b Avg       100.000000
# Fwd Pkts/b Avg       100.000000
# Fwd Blk Rate Avg     100.000000
# Bwd Byts/b Avg       100.000000
# Bwd Pkts/b Avg       100.000000
# Bwd Blk Rate Avg     100.000000
# Subflow Fwd Pkts       0.262414
# Subflow Fwd Byts      49.973775
# Subflow Bwd Pkts       0.000000
# Subflow Bwd Byts      49.681542
# Init Fwd Win Byts      0.000000
# Init Bwd Win Byts      6.085336
# Fwd Act Data Pkts     49.973775
# Fwd Seg Size Min     100.000000
# Active Mean           61.485334
# Active Std            94.364744
# Active Max            61.485334
# Active Min            61.485334
# Idle Mean             31.805534
# Idle Std              52.276969
# Idle Max              31.805534
# Idle Min              31.805534
# Label                  0.000000
# dtype: float64
