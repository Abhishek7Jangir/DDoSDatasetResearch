# %%
import pandas as pd

# We use 2017 as the template to grab the exact column headers
reference_file = "anon-Booter_Combined.csv" 
output_file = "leave_CIC19.csv"

# Read only headers
df_ref = pd.read_csv(reference_file, nrows=0)

# Rename the 3 culprit columns to match the target schema
df_ref = df_ref.rename(columns={
    'Fwd Pkts/s': 'Fwd Packets/s',
    'Bwd Pkts/s': 'Bwd Packets/s',
    'Bwd IAT Tot': 'Bwd IAT Total'
})

# Create the empty master file
df_ref.to_csv(output_file, index=False)
print(f"Master schema created: {output_file}")
# Out:
# Master schema created: leave_CIC19.csv

# %%
import pandas as pd
import numpy as np

# ==========================================
# 1. CONFIGURATION
# ==========================================
current_file_path = "caida_dataset_2007_Combined.csv"
current_dataset_name = "caida"

big_file = "leave_CIC19.csv"
n = 5933   # attack total samples
m = 0   # benign samples 

print(f"Starting processing for dataset: {current_dataset_name.upper()}")
print("-" * 50)

# ==========================================
# 2. LOAD DATA
# ==========================================
big_columns = pd.read_csv(big_file, nrows=0).columns.tolist()
df = pd.read_csv(current_file_path)

df = df.rename(columns={
    'Fwd Pkts/s': 'Fwd Packets/s',
    'Bwd Pkts/s': 'Bwd Packets/s',
    'Bwd IAT Tot': 'Bwd IAT Total'
})

print(f"Original row count: {len(df)}")

# ❌ REMOVED NaN/Inf cleaning step as requested

# ==========================================
# 3. LABEL ROUTER
# ==========================================
df['Label'] = df['Label'].astype(str).str.strip().str.upper()

known_benign_indicators = ["BENIGN", "0", "NORMAL"]
known_invalid_indicators = ["NONE", "NULL", "NAN", ""]

rows_before_trash = len(df)
df = df[~df['Label'].isin(known_invalid_indicators)]
dropped_invalid = rows_before_trash - len(df)

if dropped_invalid > 0:
    print(f"Cleaned Label count: {len(df)} (Dropped {dropped_invalid} corrupted labels)")

df_benign_source = df[df['Label'].isin(known_benign_indicators)]
df_attack_source = df[~df['Label'].isin(known_benign_indicators)]

# ==========================================
# 4. BENIGN PROCESSING (NOW USES m)
# ==========================================
if not df_benign_source.empty:
    benign_sample_size = min(m, len(df_benign_source))
    df_benign = df_benign_source.sample(n=benign_sample_size, random_state=42).copy()
    df_benign['Label'] = 0
else:
    df_benign = pd.DataFrame()
    benign_sample_size = 0

# ==========================================
# 5. ATTACK PROCESSING (UNCHANGED USING n)
# ==========================================
if not df_attack_source.empty:
    attack_classes = df_attack_source['Label'].unique()
    num_classes = len(attack_classes)
    target_per_class = n // num_classes

    print(f"Auto-detected {num_classes} distinct attack class(es).")
    print(f"Targeting {target_per_class} records per class.")

    attack_samples = []

    for attack_class in attack_classes:
        class_data = df_attack_source[df_attack_source['Label'] == attack_class]
        sample_size = min(target_per_class, len(class_data))
        attack_samples.append(class_data.sample(n=sample_size, random_state=42).copy())

    df_attack = pd.concat(attack_samples, ignore_index=True)
    df_attack['Label'] = 1
else:
    df_attack = pd.DataFrame()

# ==========================================
# 6. COMBINE & APPEND
# ==========================================
df_to_append = pd.concat([df_benign, df_attack], ignore_index=True)

if not df_to_append.empty:
    df_to_append = df_to_append.reindex(columns=big_columns)

    df_to_append.to_csv(big_file, mode='a', index=False, header=False)

    print("\nSUCCESS! Summary:")
    print(f"  -> Benign Rows: {benign_sample_size} (m-based)")
    print(f"  -> Attack Rows: {len(df_attack)} (n-based)")
    print(f"  -> Total Appended: {len(df_to_append)} rows")
else:
    print("\nWARNING: No valid records found to append!")

print("-" * 50)
# Out:
# Starting processing for dataset: CAIDA
# --------------------------------------------------
# Original row count: 2471740
# Auto-detected 1 distinct attack class(es).
# Targeting 5933 records per class.
#
# SUCCESS! Summary:
#   -> Benign Rows: 0 (m-based)
#   -> Attack Rows: 5933 (n-based)
#   -> Total Appended: 5933 rows
# --------------------------------------------------

# %%
import pandas as pd
import numpy as np

# ==========================================
# 1. CONFIGURATION
# ==========================================
current_file_path = "IoT_Dataset_HTTP_DDoS.csv"
current_dataset_name = "bot"

big_file = "leave_CIC19.csv"
n = 1977   # attack total samples
m = 0   # benign samples 

print(f"Starting processing for dataset: {current_dataset_name.upper()}")
print("-" * 50)

# ==========================================
# 2. LOAD DATA
# ==========================================
big_columns = pd.read_csv(big_file, nrows=0).columns.tolist()
df = pd.read_csv(current_file_path)

df = df.rename(columns={
    'Fwd Pkts/s': 'Fwd Packets/s',
    'Bwd Pkts/s': 'Bwd Packets/s',
    'Bwd IAT Tot': 'Bwd IAT Total'
})

print(f"Original row count: {len(df)}")

# ❌ REMOVED NaN/Inf cleaning step as requested

# ==========================================
# 3. LABEL ROUTER
# ==========================================
df['Label'] = df['Label'].astype(str).str.strip().str.upper()

known_benign_indicators = ["BENIGN", "0", "NORMAL"]
known_invalid_indicators = ["NONE", "NULL", "NAN", ""]

rows_before_trash = len(df)
df = df[~df['Label'].isin(known_invalid_indicators)]
dropped_invalid = rows_before_trash - len(df)

if dropped_invalid > 0:
    print(f"Cleaned Label count: {len(df)} (Dropped {dropped_invalid} corrupted labels)")

df_benign_source = df[df['Label'].isin(known_benign_indicators)]
df_attack_source = df[~df['Label'].isin(known_benign_indicators)]

# ==========================================
# 4. BENIGN PROCESSING (NOW USES m)
# ==========================================
if not df_benign_source.empty:
    benign_sample_size = min(m, len(df_benign_source))
    df_benign = df_benign_source.sample(n=benign_sample_size, random_state=42).copy()
    df_benign['Label'] = 0
else:
    df_benign = pd.DataFrame()
    benign_sample_size = 0

# ==========================================
# 5. ATTACK PROCESSING (UNCHANGED USING n)
# ==========================================
if not df_attack_source.empty:
    attack_classes = df_attack_source['Label'].unique()
    num_classes = len(attack_classes)
    target_per_class = n // num_classes

    print(f"Auto-detected {num_classes} distinct attack class(es).")
    print(f"Targeting {target_per_class} records per class.")

    attack_samples = []

    for attack_class in attack_classes:
        class_data = df_attack_source[df_attack_source['Label'] == attack_class]
        sample_size = min(target_per_class, len(class_data))
        attack_samples.append(class_data.sample(n=sample_size, random_state=42).copy())

    df_attack = pd.concat(attack_samples, ignore_index=True)
    df_attack['Label'] = 1
else:
    df_attack = pd.DataFrame()

# ==========================================
# 6. COMBINE & APPEND
# ==========================================
df_to_append = pd.concat([df_benign, df_attack], ignore_index=True)

if not df_to_append.empty:
    df_to_append = df_to_append.reindex(columns=big_columns)

    df_to_append.to_csv(big_file, mode='a', index=False, header=False)

    print("\nSUCCESS! Summary:")
    print(f"  -> Benign Rows: {benign_sample_size} (m-based)")
    print(f"  -> Attack Rows: {len(df_attack)} (n-based)")
    print(f"  -> Total Appended: {len(df_to_append)} rows")
else:
    print("\nWARNING: No valid records found to append!")

print("-" * 50)
# Out:
# Starting processing for dataset: BOT
# --------------------------------------------------
# Original row count: 35133
# Auto-detected 1 distinct attack class(es).
# Targeting 1977 records per class.
#
# SUCCESS! Summary:
#   -> Benign Rows: 0 (m-based)
#   -> Attack Rows: 1977 (n-based)
#   -> Total Appended: 1977 rows
# --------------------------------------------------

# %%
import pandas as pd
import numpy as np

# ==========================================
# 1. CONFIGURATION
# ==========================================
current_file_path = "IoT_Dataset_TCP_DDoS.csv"
current_dataset_name = "bot"

big_file = "leave_CIC19.csv"
n = 1978   # attack total samples
m = 0   # benign samples 

print(f"Starting processing for dataset: {current_dataset_name.upper()}")
print("-" * 50)

# ==========================================
# 2. LOAD DATA
# ==========================================
big_columns = pd.read_csv(big_file, nrows=0).columns.tolist()
df = pd.read_csv(current_file_path)

df = df.rename(columns={
    'Fwd Pkts/s': 'Fwd Packets/s',
    'Bwd Pkts/s': 'Bwd Packets/s',
    'Bwd IAT Tot': 'Bwd IAT Total'
})

print(f"Original row count: {len(df)}")

# ❌ REMOVED NaN/Inf cleaning step as requested

# ==========================================
# 3. LABEL ROUTER
# ==========================================
df['Label'] = df['Label'].astype(str).str.strip().str.upper()

known_benign_indicators = ["BENIGN", "0", "NORMAL"]
known_invalid_indicators = ["NONE", "NULL", "NAN", ""]

rows_before_trash = len(df)
df = df[~df['Label'].isin(known_invalid_indicators)]
dropped_invalid = rows_before_trash - len(df)

if dropped_invalid > 0:
    print(f"Cleaned Label count: {len(df)} (Dropped {dropped_invalid} corrupted labels)")

df_benign_source = df[df['Label'].isin(known_benign_indicators)]
df_attack_source = df[~df['Label'].isin(known_benign_indicators)]

# ==========================================
# 4. BENIGN PROCESSING (NOW USES m)
# ==========================================
if not df_benign_source.empty:
    benign_sample_size = min(m, len(df_benign_source))
    df_benign = df_benign_source.sample(n=benign_sample_size, random_state=42).copy()
    df_benign['Label'] = 0
else:
    df_benign = pd.DataFrame()
    benign_sample_size = 0

# ==========================================
# 5. ATTACK PROCESSING (UNCHANGED USING n)
# ==========================================
if not df_attack_source.empty:
    attack_classes = df_attack_source['Label'].unique()
    num_classes = len(attack_classes)
    target_per_class = n // num_classes

    print(f"Auto-detected {num_classes} distinct attack class(es).")
    print(f"Targeting {target_per_class} records per class.")

    attack_samples = []

    for attack_class in attack_classes:
        class_data = df_attack_source[df_attack_source['Label'] == attack_class]
        sample_size = min(target_per_class, len(class_data))
        attack_samples.append(class_data.sample(n=sample_size, random_state=42).copy())

    df_attack = pd.concat(attack_samples, ignore_index=True)
    df_attack['Label'] = 1
else:
    df_attack = pd.DataFrame()

# ==========================================
# 6. COMBINE & APPEND
# ==========================================
df_to_append = pd.concat([df_benign, df_attack], ignore_index=True)

if not df_to_append.empty:
    df_to_append = df_to_append.reindex(columns=big_columns)

    df_to_append.to_csv(big_file, mode='a', index=False, header=False)

    print("\nSUCCESS! Summary:")
    print(f"  -> Benign Rows: {benign_sample_size} (m-based)")
    print(f"  -> Attack Rows: {len(df_attack)} (n-based)")
    print(f"  -> Total Appended: {len(df_to_append)} rows")
else:
    print("\nWARNING: No valid records found to append!")

print("-" * 50)
# Out:
# Starting processing for dataset: BOT
# --------------------------------------------------
# Original row count: 19135761
# Auto-detected 1 distinct attack class(es).
# Targeting 1978 records per class.
#
# SUCCESS! Summary:
#   -> Benign Rows: 0 (m-based)
#   -> Attack Rows: 1978 (n-based)
#   -> Total Appended: 1978 rows
# --------------------------------------------------

# %%
import pandas as pd
import numpy as np

# ==========================================
# 1. CONFIGURATION
# ==========================================
current_file_path = "IoT_Dataset_UDP_DDoS.csv"
current_dataset_name = "bot"

big_file = "leave_CIC19.csv"
n = 1978   # attack total samples
m = 0   # benign samples 

print(f"Starting processing for dataset: {current_dataset_name.upper()}")
print("-" * 50)

# ==========================================
# 2. LOAD DATA
# ==========================================
big_columns = pd.read_csv(big_file, nrows=0).columns.tolist()
df = pd.read_csv(current_file_path)

df = df.rename(columns={
    'Fwd Pkts/s': 'Fwd Packets/s',
    'Bwd Pkts/s': 'Bwd Packets/s',
    'Bwd IAT Tot': 'Bwd IAT Total'
})

print(f"Original row count: {len(df)}")

# ❌ REMOVED NaN/Inf cleaning step as requested

# ==========================================
# 3. LABEL ROUTER
# ==========================================
df['Label'] = df['Label'].astype(str).str.strip().str.upper()

known_benign_indicators = ["BENIGN", "0", "NORMAL"]
known_invalid_indicators = ["NONE", "NULL", "NAN", ""]

rows_before_trash = len(df)
df = df[~df['Label'].isin(known_invalid_indicators)]
dropped_invalid = rows_before_trash - len(df)

if dropped_invalid > 0:
    print(f"Cleaned Label count: {len(df)} (Dropped {dropped_invalid} corrupted labels)")

df_benign_source = df[df['Label'].isin(known_benign_indicators)]
df_attack_source = df[~df['Label'].isin(known_benign_indicators)]

# ==========================================
# 4. BENIGN PROCESSING (NOW USES m)
# ==========================================
if not df_benign_source.empty:
    benign_sample_size = min(m, len(df_benign_source))
    df_benign = df_benign_source.sample(n=benign_sample_size, random_state=42).copy()
    df_benign['Label'] = 0
else:
    df_benign = pd.DataFrame()
    benign_sample_size = 0

# ==========================================
# 5. ATTACK PROCESSING (UNCHANGED USING n)
# ==========================================
if not df_attack_source.empty:
    attack_classes = df_attack_source['Label'].unique()
    num_classes = len(attack_classes)
    target_per_class = n // num_classes

    print(f"Auto-detected {num_classes} distinct attack class(es).")
    print(f"Targeting {target_per_class} records per class.")

    attack_samples = []

    for attack_class in attack_classes:
        class_data = df_attack_source[df_attack_source['Label'] == attack_class]
        sample_size = min(target_per_class, len(class_data))
        attack_samples.append(class_data.sample(n=sample_size, random_state=42).copy())

    df_attack = pd.concat(attack_samples, ignore_index=True)
    df_attack['Label'] = 1
else:
    df_attack = pd.DataFrame()

# ==========================================
# 6. COMBINE & APPEND
# ==========================================
df_to_append = pd.concat([df_benign, df_attack], ignore_index=True)

if not df_to_append.empty:
    df_to_append = df_to_append.reindex(columns=big_columns)

    df_to_append.to_csv(big_file, mode='a', index=False, header=False)

    print("\nSUCCESS! Summary:")
    print(f"  -> Benign Rows: {benign_sample_size} (m-based)")
    print(f"  -> Attack Rows: {len(df_attack)} (n-based)")
    print(f"  -> Total Appended: {len(df_to_append)} rows")
else:
    print("\nWARNING: No valid records found to append!")

print("-" * 50)
# Out:
# Starting processing for dataset: BOT
# --------------------------------------------------
# Original row count: 18878169
# Auto-detected 1 distinct attack class(es).
# Targeting 1978 records per class.
#
# SUCCESS! Summary:
#   -> Benign Rows: 0 (m-based)
#   -> Attack Rows: 1978 (n-based)
#   -> Total Appended: 1978 rows
# --------------------------------------------------

# %%
import pandas as pd
import numpy as np

# ==========================================
# 1. CONFIGURATION
# ==========================================
current_file_path = "anon-Booter_Combined.csv"
current_dataset_name = "booters"

big_file = "leave_CIC19.csv"
n = 5933   # attack total samples
m = 0   # benign samples 

print(f"Starting processing for dataset: {current_dataset_name.upper()}")
print("-" * 50)

# ==========================================
# 2. LOAD DATA
# ==========================================
big_columns = pd.read_csv(big_file, nrows=0).columns.tolist()
df = pd.read_csv(current_file_path)

df = df.rename(columns={
    'Fwd Pkts/s': 'Fwd Packets/s',
    'Bwd Pkts/s': 'Bwd Packets/s',
    'Bwd IAT Tot': 'Bwd IAT Total'
})

print(f"Original row count: {len(df)}")

# ❌ REMOVED NaN/Inf cleaning step as requested

# ==========================================
# 3. LABEL ROUTER
# ==========================================
df['Label'] = df['Label'].astype(str).str.strip().str.upper()

known_benign_indicators = ["BENIGN", "0", "NORMAL"]
known_invalid_indicators = ["NONE", "NULL", "NAN", ""]

rows_before_trash = len(df)
df = df[~df['Label'].isin(known_invalid_indicators)]
dropped_invalid = rows_before_trash - len(df)

if dropped_invalid > 0:
    print(f"Cleaned Label count: {len(df)} (Dropped {dropped_invalid} corrupted labels)")

df_benign_source = df[df['Label'].isin(known_benign_indicators)]
df_attack_source = df[~df['Label'].isin(known_benign_indicators)]

# ==========================================
# 4. BENIGN PROCESSING (NOW USES m)
# ==========================================
if not df_benign_source.empty:
    benign_sample_size = min(m, len(df_benign_source))
    df_benign = df_benign_source.sample(n=benign_sample_size, random_state=42).copy()
    df_benign['Label'] = 0
else:
    df_benign = pd.DataFrame()
    benign_sample_size = 0

# ==========================================
# 5. ATTACK PROCESSING (UNCHANGED USING n)
# ==========================================
if not df_attack_source.empty:
    attack_classes = df_attack_source['Label'].unique()
    num_classes = len(attack_classes)
    target_per_class = n // num_classes

    print(f"Auto-detected {num_classes} distinct attack class(es).")
    print(f"Targeting {target_per_class} records per class.")

    attack_samples = []

    for attack_class in attack_classes:
        class_data = df_attack_source[df_attack_source['Label'] == attack_class]
        sample_size = min(target_per_class, len(class_data))
        attack_samples.append(class_data.sample(n=sample_size, random_state=42).copy())

    df_attack = pd.concat(attack_samples, ignore_index=True)
    df_attack['Label'] = 1
else:
    df_attack = pd.DataFrame()

# ==========================================
# 6. COMBINE & APPEND
# ==========================================
df_to_append = pd.concat([df_benign, df_attack], ignore_index=True)

if not df_to_append.empty:
    df_to_append = df_to_append.reindex(columns=big_columns)

    df_to_append.to_csv(big_file, mode='a', index=False, header=False)

    print("\nSUCCESS! Summary:")
    print(f"  -> Benign Rows: {benign_sample_size} (m-based)")
    print(f"  -> Attack Rows: {len(df_attack)} (n-based)")
    print(f"  -> Total Appended: {len(df_to_append)} rows")
else:
    print("\nWARNING: No valid records found to append!")

print("-" * 50)
# Out:
# Starting processing for dataset: BOOTERS
# --------------------------------------------------
# Original row count: 1771055
# Auto-detected 1 distinct attack class(es).
# Targeting 5933 records per class.
#
# SUCCESS! Summary:
#   -> Benign Rows: 0 (m-based)
#   -> Attack Rows: 5933 (n-based)
#   -> Total Appended: 5933 rows
# --------------------------------------------------

# %%
import pandas as pd
import numpy as np

# ==========================================
# 1. CONFIGURATION
# ==========================================
current_file_path = "CIC-IDS-2017_Binary.csv"
current_dataset_name = "cic17"

big_file = "leave_CIC19.csv"
n = 5933   # attack total samples
m = 20765   # benign samples 

print(f"Starting processing for dataset: {current_dataset_name.upper()}")
print("-" * 50)

# ==========================================
# 2. LOAD DATA
# ==========================================
big_columns = pd.read_csv(big_file, nrows=0).columns.tolist()
df = pd.read_csv(current_file_path)

df = df.rename(columns={
    'Fwd Pkts/s': 'Fwd Packets/s',
    'Bwd Pkts/s': 'Bwd Packets/s',
    'Bwd IAT Tot': 'Bwd IAT Total'
})

print(f"Original row count: {len(df)}")

# ❌ REMOVED NaN/Inf cleaning step as requested

# ==========================================
# 3. LABEL ROUTER
# ==========================================
df['Label'] = df['Label'].astype(str).str.strip().str.upper()

known_benign_indicators = ["BENIGN", "0", "NORMAL"]
known_invalid_indicators = ["NONE", "NULL", "NAN", ""]

rows_before_trash = len(df)
df = df[~df['Label'].isin(known_invalid_indicators)]
dropped_invalid = rows_before_trash - len(df)

if dropped_invalid > 0:
    print(f"Cleaned Label count: {len(df)} (Dropped {dropped_invalid} corrupted labels)")

df_benign_source = df[df['Label'].isin(known_benign_indicators)]
df_attack_source = df[~df['Label'].isin(known_benign_indicators)]

# ==========================================
# 4. BENIGN PROCESSING (NOW USES m)
# ==========================================
if not df_benign_source.empty:
    benign_sample_size = min(m, len(df_benign_source))
    df_benign = df_benign_source.sample(n=benign_sample_size, random_state=42).copy()
    df_benign['Label'] = 0
else:
    df_benign = pd.DataFrame()
    benign_sample_size = 0

# ==========================================
# 5. ATTACK PROCESSING (UNCHANGED USING n)
# ==========================================
if not df_attack_source.empty:
    attack_classes = df_attack_source['Label'].unique()
    num_classes = len(attack_classes)
    target_per_class = n // num_classes

    print(f"Auto-detected {num_classes} distinct attack class(es).")
    print(f"Targeting {target_per_class} records per class.")

    attack_samples = []

    for attack_class in attack_classes:
        class_data = df_attack_source[df_attack_source['Label'] == attack_class]
        sample_size = min(target_per_class, len(class_data))
        attack_samples.append(class_data.sample(n=sample_size, random_state=42).copy())

    df_attack = pd.concat(attack_samples, ignore_index=True)
    df_attack['Label'] = 1
else:
    df_attack = pd.DataFrame()

# ==========================================
# 6. COMBINE & APPEND
# ==========================================
df_to_append = pd.concat([df_benign, df_attack], ignore_index=True)

if not df_to_append.empty:
    df_to_append = df_to_append.reindex(columns=big_columns)

    df_to_append.to_csv(big_file, mode='a', index=False, header=False)

    print("\nSUCCESS! Summary:")
    print(f"  -> Benign Rows: {benign_sample_size} (m-based)")
    print(f"  -> Attack Rows: {len(df_attack)} (n-based)")
    print(f"  -> Total Appended: {len(df_to_append)} rows")
else:
    print("\nWARNING: No valid records found to append!")

print("-" * 50)
# Out:
# Starting processing for dataset: CIC17
# --------------------------------------------------
# Original row count: 2830743
# Auto-detected 1 distinct attack class(es).
# Targeting 5933 records per class.
#
# SUCCESS! Summary:
#   -> Benign Rows: 20765 (m-based)
#   -> Attack Rows: 5933 (n-based)
#   -> Total Appended: 26698 rows
# --------------------------------------------------

# %%
import pandas as pd
import numpy as np

# ==========================================
# 1. CONFIGURATION
# ==========================================
current_file_path = "CSC_CIC_02-20-2018.csv"
current_dataset_name = "cic18"

big_file = "leave_CIC19.csv"
n = 5933   # attack total samples
m = 20766   # benign samples 

print(f"Starting processing for dataset: {current_dataset_name.upper()}")
print("-" * 50)

# ==========================================
# 2. LOAD DATA
# ==========================================
big_columns = pd.read_csv(big_file, nrows=0).columns.tolist()
df = pd.read_csv(current_file_path)

df = df.rename(columns={
    'Fwd Pkts/s': 'Fwd Packets/s',
    'Bwd Pkts/s': 'Bwd Packets/s',
    'Bwd IAT Tot': 'Bwd IAT Total'
})

print(f"Original row count: {len(df)}")

# ❌ REMOVED NaN/Inf cleaning step as requested

# ==========================================
# 3. LABEL ROUTER
# ==========================================
df['Label'] = df['Label'].astype(str).str.strip().str.upper()

known_benign_indicators = ["BENIGN", "0", "NORMAL"]
known_invalid_indicators = ["NONE", "NULL", "NAN", ""]

rows_before_trash = len(df)
df = df[~df['Label'].isin(known_invalid_indicators)]
dropped_invalid = rows_before_trash - len(df)

if dropped_invalid > 0:
    print(f"Cleaned Label count: {len(df)} (Dropped {dropped_invalid} corrupted labels)")

df_benign_source = df[df['Label'].isin(known_benign_indicators)]
df_attack_source = df[~df['Label'].isin(known_benign_indicators)]

# ==========================================
# 4. BENIGN PROCESSING (NOW USES m)
# ==========================================
if not df_benign_source.empty:
    benign_sample_size = min(m, len(df_benign_source))
    df_benign = df_benign_source.sample(n=benign_sample_size, random_state=42).copy()
    df_benign['Label'] = 0
else:
    df_benign = pd.DataFrame()
    benign_sample_size = 0

# ==========================================
# 5. ATTACK PROCESSING (UNCHANGED USING n)
# ==========================================
if not df_attack_source.empty:
    attack_classes = df_attack_source['Label'].unique()
    num_classes = len(attack_classes)
    target_per_class = n // num_classes

    print(f"Auto-detected {num_classes} distinct attack class(es).")
    print(f"Targeting {target_per_class} records per class.")

    attack_samples = []

    for attack_class in attack_classes:
        class_data = df_attack_source[df_attack_source['Label'] == attack_class]
        sample_size = min(target_per_class, len(class_data))
        attack_samples.append(class_data.sample(n=sample_size, random_state=42).copy())

    df_attack = pd.concat(attack_samples, ignore_index=True)
    df_attack['Label'] = 1
else:
    df_attack = pd.DataFrame()

# ==========================================
# 6. COMBINE & APPEND
# ==========================================
df_to_append = pd.concat([df_benign, df_attack], ignore_index=True)

if not df_to_append.empty:
    df_to_append = df_to_append.reindex(columns=big_columns)

    df_to_append.to_csv(big_file, mode='a', index=False, header=False)

    print("\nSUCCESS! Summary:")
    print(f"  -> Benign Rows: {benign_sample_size} (m-based)")
    print(f"  -> Attack Rows: {len(df_attack)} (n-based)")
    print(f"  -> Total Appended: {len(df_to_append)} rows")
else:
    print("\nWARNING: No valid records found to append!")

print("-" * 50)
# Out:
# Starting processing for dataset: CIC18
# --------------------------------------------------
# Original row count: 7948748
# Auto-detected 1 distinct attack class(es).
# Targeting 5933 records per class.
#
# SUCCESS! Summary:
#   -> Benign Rows: 20766 (m-based)
#   -> Attack Rows: 5933 (n-based)
#   -> Total Appended: 26699 rows
# --------------------------------------------------

# %%
import pandas as pd
import numpy as np

# ==========================================
# 1. CONFIGURATION
# ==========================================
current_file_path = "CTU-13.csv"
current_dataset_name = "ctu13"

big_file = "leave_CIC19.csv"
n = 5933   # attack total samples
m = 0   # benign samples 

print(f"Starting processing for dataset: {current_dataset_name.upper()}")
print("-" * 50)

# ==========================================
# 2. LOAD DATA
# ==========================================
big_columns = pd.read_csv(big_file, nrows=0).columns.tolist()
df = pd.read_csv(current_file_path)

df = df.rename(columns={
    'Fwd Pkts/s': 'Fwd Packets/s',
    'Bwd Pkts/s': 'Bwd Packets/s',
    'Bwd IAT Tot': 'Bwd IAT Total'
})

print(f"Original row count: {len(df)}")

# ❌ REMOVED NaN/Inf cleaning step as requested

# ==========================================
# 3. LABEL ROUTER
# ==========================================
df['Label'] = df['Label'].astype(str).str.strip().str.upper()

known_benign_indicators = ["BENIGN", "0", "NORMAL"]
known_invalid_indicators = ["NONE", "NULL", "NAN", ""]

rows_before_trash = len(df)
df = df[~df['Label'].isin(known_invalid_indicators)]
dropped_invalid = rows_before_trash - len(df)

if dropped_invalid > 0:
    print(f"Cleaned Label count: {len(df)} (Dropped {dropped_invalid} corrupted labels)")

df_benign_source = df[df['Label'].isin(known_benign_indicators)]
df_attack_source = df[~df['Label'].isin(known_benign_indicators)]

# ==========================================
# 4. BENIGN PROCESSING (NOW USES m)
# ==========================================
if not df_benign_source.empty:
    benign_sample_size = min(m, len(df_benign_source))
    df_benign = df_benign_source.sample(n=benign_sample_size, random_state=42).copy()
    df_benign['Label'] = 0
else:
    df_benign = pd.DataFrame()
    benign_sample_size = 0

# ==========================================
# 5. ATTACK PROCESSING (UNCHANGED USING n)
# ==========================================
if not df_attack_source.empty:
    attack_classes = df_attack_source['Label'].unique()
    num_classes = len(attack_classes)
    target_per_class = n // num_classes

    print(f"Auto-detected {num_classes} distinct attack class(es).")
    print(f"Targeting {target_per_class} records per class.")

    attack_samples = []

    for attack_class in attack_classes:
        class_data = df_attack_source[df_attack_source['Label'] == attack_class]
        sample_size = min(target_per_class, len(class_data))
        attack_samples.append(class_data.sample(n=sample_size, random_state=42).copy())

    df_attack = pd.concat(attack_samples, ignore_index=True)
    df_attack['Label'] = 1
else:
    df_attack = pd.DataFrame()

# ==========================================
# 6. COMBINE & APPEND
# ==========================================
df_to_append = pd.concat([df_benign, df_attack], ignore_index=True)

if not df_to_append.empty:
    df_to_append = df_to_append.reindex(columns=big_columns)

    df_to_append.to_csv(big_file, mode='a', index=False, header=False)

    print("\nSUCCESS! Summary:")
    print(f"  -> Benign Rows: {benign_sample_size} (m-based)")
    print(f"  -> Attack Rows: {len(df_attack)} (n-based)")
    print(f"  -> Total Appended: {len(df_to_append)} rows")
else:
    print("\nWARNING: No valid records found to append!")

print("-" * 50)
# Out:
# Starting processing for dataset: CTU13
# --------------------------------------------------
# Original row count: 5933
# Auto-detected 1 distinct attack class(es).
# Targeting 5933 records per class.
#
# SUCCESS! Summary:
#   -> Benign Rows: 0 (m-based)
#   -> Attack Rows: 5933 (n-based)
#   -> Total Appended: 5933 rows
# --------------------------------------------------

# %%
import pandas as np

df = pd.read_csv("leave_CIC19.csv")
df['Label'].value_counts()
# Out:
# Label
# 0    41531
# 1    35598
# Name: count, dtype: int64

# %%
import pandas as pd

# Load dataset
file_path = "leave_CIC19.csv"
df = pd.read_csv(file_path)

# Count samples in each class
count_0 = (df['Label'] == 0).sum()
count_1 = (df['Label'] == 1).sum()

print("Before balancing:")
print(df['Label'].value_counts())

# Determine minority class size
target_size = min(count_0, count_1)

# Sample equal numbers from each class
df_0 = df[df['Label'] == 0].sample(n=target_size, random_state=42)
df_1 = df[df['Label'] == 1].sample(n=target_size, random_state=42)

# Combine and shuffle
df_balanced = pd.concat([df_0, df_1], ignore_index=True)
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# Save back to the same file
df_balanced.to_csv(file_path, index=False)

print("\nAfter balancing:")
print(df_balanced['Label'].value_counts())

print(f"\nSaved balanced dataset to: {file_path}")
# Out:
# Before balancing:
# Label
# 0    41531
# 1    35598
# Name: count, dtype: int64
#
# After balancing:
# Label
# 1    35598
# 0    35598
# Name: count, dtype: int64
#
# Saved balanced dataset to: leave_CIC19.csv
